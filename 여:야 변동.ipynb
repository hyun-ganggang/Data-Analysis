# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family=fontprop.get_name())

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path_18 = '/content/drive/My Drive/data/18대 대선.csv'
file_path_19 = '/content/drive/My Drive/data/19대 대선.csv'
file_path_20 = '/content/drive/My Drive/data/20대 대선.csv'

# 18대 대선 데이터 불러오기
df_18 = pd.read_csv(file_path_18, encoding='utf-8')

# 19대 대선 데이터 불러오기
df_19 = pd.read_csv(file_path_19, encoding='utf-8')

# 20대 대선 데이터 불러오기
df_20 = pd.read_csv(file_path_20, encoding='utf-8')

# 선거구명을 문자열로 변환
df_18['선거구명'] = df_18['선거구명'].astype(str)
df_19['선거구명'] = df_19['선거구명'].astype(str)
df_20['선거구명'] = df_20['선거구명'].astype(str)

# 18대 대선 데이터 정렬
df_18_sorted = df_18.sort_values('선거구명')
x_18 = df_18_sorted['선거구명']
y_18 = df_18_sorted['여득표율 - 야득표율']

# 19대 대선 데이터 정렬
df_19_sorted = df_19.sort_values('선거구명')
x_19 = df_19_sorted['선거구명']
y_19 = df_19_sorted['여득표율 - 야득표율']

# 20대 대선 데이터 정렬
df_20_sorted = df_20.sort_values('선거구명')
x_20 = df_20_sorted['선거구명']
y_20 = df_20_sorted['여득표율 - 야득표율']

# 선 그래프 생성
plt.figure(figsize=(12, 8))
plt.plot(x_18, y_18, marker='o', linestyle='-', color='red', label='18대')
plt.plot(x_19, y_19, marker='o', linestyle='-', color='blue', label='19대')
plt.plot(x_20, y_20, marker='o', linestyle='-', color='coral', label='20대')

plt.title('18대, 19대, 20대 대선 선거구별 득표율 차', fontproperties=fontprop, fontsize=16)
plt.xlabel('선거구명', fontproperties=fontprop, fontsize=12)
plt.ylabel('득표율 차', fontproperties=fontprop, fontsize=12)
plt.xticks(rotation=90, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(fontproperties=fontprop, fontsize=10)
plt.legend(prop=fontprop)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-5-fbe91f55891d>:66: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fm.fontManager.addfont(font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path_18 = '/content/drive/My Drive/data/18대 대선.csv'
file_path_19 = '/content/drive/My Drive/data/19대 대선.csv'
file_path_20 = '/content/drive/My Drive/data/20대 대선.csv'


# 18대 대선 데이터 불러오기
df_18 = pd.read_csv(file_path_18, encoding='utf-8')


# 19대 대선 데이터 불러오기
df_19 = pd.read_csv(file_path_19, encoding='utf-8')


# 20대 대선 데이터 불러오기
df_20 = pd.read_csv(file_path_20, encoding='utf-8')



# 선거구명을 문자열로 변환
df_18['선거구명'] = df_18['선거구명'].astype(str)
df_19['선거구명'] = df_19['선거구명'].astype(str)
df_20['선거구명'] = df_20['선거구명'].astype(str)

# 세 데이터프레임을 하나로 합치기
df_all = pd.concat([df_18, df_19, df_20], ignore_index=True)

# 박스 플롯 생성
plt.figure(figsize=(12, 8))
sns.boxplot(x='선거구명', y='여득표율 - 야득표율', data=df_all)

# y축 0에 해당하는 가로선을 빨간색으로 그리기
plt.axhline(y=0, color='red', linestyle='--', linewidth=2)

plt.title('18대, 19대, 20대 대선 선거구별 득표율 차', fontsize=16)
plt.xlabel('선거구명', fontsize=12)
plt.ylabel('득표율 차', fontsize=12)
plt.xticks(rotation=90, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <ipython-input-7-00a17598c91c>:59: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path_20 = '/content/drive/My Drive/data/20대 총선.csv'
file_path_21 = '/content/drive/My Drive/data/21대 총선.csv'
file_path_22 = '/content/drive/My Drive/data/22대 총선.csv'


# 20대 총선 데이터 불러오기
df_20 = pd.read_csv(file_path_20, encoding='utf-8')

# 21대 총선 데이터 불러오기
df_21 = pd.read_csv(file_path_21, encoding='utf-8')

# 22대 총선 데이터 불러오기
df_22 = pd.read_csv(file_path_22, encoding='utf-8')


# 선거구명을 문자열로 변환
df_20['선거구명'] = df_20['선거구명'].astype(str)
df_21['선거구명'] = df_21['선거구명'].astype(str)
df_22['선거구명'] = df_22['선거구명'].astype(str)

# 20대 총선 데이터 정렬
df_20_sorted = df_20.sort_values('선거구명')
x_20 = df_20_sorted['선거구명']
y_20 = df_20_sorted['여득표율 - 야득표율']

# 21대 총선 데이터 정렬
df_21_sorted = df_21.sort_values('선거구명')
x_21 = df_21_sorted['선거구명']
y_21 = df_21_sorted['여득표율 - 야득표율']

# 22대 총선 데이터 정렬
df_22_sorted = df_22.sort_values('선거구명')
x_22 = df_22_sorted['선거구명']
y_22 = df_22_sorted['여득표율 - 야득표율']

# 선 그래프 생성
plt.figure(figsize=(12, 8))
plt.plot(x_20, y_20, marker='o', linestyle='-', color='skyblue', label='20대 총선')
plt.plot(x_21, y_21, marker='o', linestyle='-', color='coral', label='21대 총선')
plt.plot(x_22, y_22, marker='o', linestyle='-', color='green', label='22대 총선')

plt.title('20대, 21대, 22대 총선 선거구별 득표율 차', fontproperties=fontprop, fontsize=16)
plt.xlabel('선거구명', fontproperties=fontprop, fontsize=12)
plt.ylabel('득표율 차', fontproperties=fontprop, fontsize=12)
plt.xticks(rotation=90, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(fontproperties=fontprop, fontsize=10)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-8-9b83970e4a00>:68: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fm.fontManager.addfont(font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path_20 = '/content/drive/My Drive/data/20대 총선.csv'
file_path_21 = '/content/drive/My Drive/data/21대 총선.csv'
file_path_22 = '/content/drive/My Drive/data/22대 총선.csv'

# 20대 총선 데이터 불러오기
df_20 = pd.read_csv(file_path_20, encoding='utf-8')

# 21대 총선 데이터 불러오기
df_21 = pd.read_csv(file_path_21, encoding='utf-8')

# 22대 총선 데이터 불러오기
df_22 = pd.read_csv(file_path_22, encoding='utf-8')

# 선거구명을 문자열로 변환
df_20['선거구명'] = df_20['선거구명'].astype(str)
df_21['선거구명'] = df_21['선거구명'].astype(str)
df_22['선거구명'] = df_22['선거구명'].astype(str)

# 세 데이터프레임을 하나로 합치기
df_all = pd.concat([df_20, df_21, df_22], ignore_index=True)

# 박스 플롯 생성
plt.figure(figsize=(12, 8))
sns.boxplot(x='선거구명', y='여득표율 - 야득표율', data=df_all)

# y축 0에 해당하는 가로선을 빨간색으로 그리기
plt.axhline(y=0, color='red', linestyle='--', linewidth=2)

plt.title('20대, 21대, 22대 총선 선거구별 득표율 차', fontsize=16)
plt.xlabel('선거구명', fontsize=12)
plt.ylabel('득표율 차', fontsize=12)
plt.xticks(rotation=90, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <ipython-input-9-154a84a747ff>:54: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fm.fontManager.addfont(font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path_19 = '/content/drive/My Drive/data/19대 총선_비례.csv'
file_path_20 = '/content/drive/My Drive/data/20대 총선_비례.csv'
file_path_21 = '/content/drive/My Drive/data/21대 총선_비례.csv'
file_path_22 = '/content/drive/My Drive/data/22대 총선_비례.csv'

# 19대 총선 데이터 불러오기
df_19 = pd.read_csv(file_path_19, encoding='utf-8')

# 20대 총선 데이터 불러오기
df_20 = pd.read_csv(file_path_20, encoding='utf-8')

# 21대 총선 데이터 불러오기
df_21 = pd.read_csv(file_path_21, encoding='utf-8')

# 22대 총선 데이터 불러오기
df_22 = pd.read_csv(file_path_22, encoding='utf-8')

# 선거구명을 문자열로 변환
df_19['선거구명'] = df_19['선거구명'].astype(str)
df_20['선거구명'] = df_20['선거구명'].astype(str)
df_21['선거구명'] = df_21['선거구명'].astype(str)
df_22['선거구명'] = df_22['선거구명'].astype(str)

# 세 데이터프레임을 하나로 합치기
df_all = pd.concat([df_19, df_20, df_21, df_22], ignore_index=True)

# 박스 플롯 생성
plt.figure(figsize=(12, 8))
sns.boxplot(x='선거구명', y='여득표율 - 야득표율', data=df_all)

# y축 0에 해당하는 가로선을 빨간색으로 그리기
plt.axhline(y=0, color='red', linestyle='--', linewidth=2)

plt.title('19대, 20대, 21대, 22대 비례대표 총선 선거구별 여득표율 - 야득표율', fontsize=16)
plt.xlabel('선거구명', fontsize=12)
plt.ylabel('여득표율 - 야득표율', fontsize=12)
plt.xticks(rotation=90, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path_19 = '/content/drive/My Drive/data/19대 총선_비례.csv'
file_path_20 = '/content/drive/My Drive/data/20대 총선_비례.csv'
file_path_21 = '/content/drive/My Drive/data/21대 총선_비례.csv'
file_path_22 = '/content/drive/My Drive/data/22대 총선_비례.csv'

# 19대 총선 데이터 불러오기
df_19 = pd.read_csv(file_path_19, encoding='utf-8')

# 20대 총선 데이터 불러오기
df_20 = pd.read_csv(file_path_20, encoding='utf-8')

# 21대 총선 데이터 불러오기
df_21 = pd.read_csv(file_path_21, encoding='utf-8')

# 22대 총선 데이터 불러오기
df_22 = pd.read_csv(file_path_22, encoding='utf-8')

#선거구명을 문자열로 변환
df_19['선거구명'] = df_19['선거구명'].astype(str)
df_20['선거구명'] = df_20['선거구명'].astype(str)
df_21['선거구명'] = df_21['선거구명'].astype(str)
df_22['선거구명'] = df_22['선거구명'].astype(str)

# 19대 총선 데이터 정렬
df_19_sorted = df_19.sort_values('선거구명')
x_19 = df_19_sorted['선거구명']
y_19 = df_19_sorted['여득표율 - 야득표율']

# 20대 총선 데이터 정렬
df_20_sorted = df_20.sort_values('선거구명')
x_20 = df_20_sorted['선거구명']
y_20 = df_20_sorted['여득표율 - 야득표율']

# 21대 총선 데이터 정렬
df_21_sorted = df_21.sort_values('선거구명')
x_21 = df_21_sorted['선거구명']
y_21 = df_21_sorted['여득표율 - 야득표율']

# 22대 총선 데이터 정렬
df_22_sorted = df_22.sort_values('선거구명')
x_22 = df_22_sorted['선거구명']
y_22 = df_22_sorted['여득표율 - 야득표율']

# 선 그래프 생성
plt.figure(figsize=(12, 8))
plt.plot(x_19, y_19, marker='o', linestyle='-', color='pink', label='19대 총선 비례')
plt.plot(x_20, y_20, marker='o', linestyle='-', color='coral', label='20대 총선 비례')
plt.plot(x_21, y_21, marker='o', linestyle='-', color='orange', label='21대 총선 비례')
plt.plot(x_22, y_22, marker='o', linestyle='-', color='red', label='22대 총선 비례')

plt.title('19대, 20대, 21대, 22대 총선 비례대표 선거구별 득표율 차이', fontproperties=fontprop, fontsize=16)
plt.xlabel('선거구명', fontproperties=fontprop, fontsize=12)
plt.ylabel('득표율 차이', fontproperties=fontprop, fontsize=12)
plt.xticks(rotation=90, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(fontproperties=fontprop, fontsize=10)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
