# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/18대 대선.csv'




# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('18대 대선', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('색상강도', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/18대 대선.csv'



# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('18대 대선', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('색상강도', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/19대 총선.csv'


# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('19대 총선', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('색상강도', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/19대 대선.csv'


# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('19대 대선', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('색상강도', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/20대 대선.csv'


# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('20대 대선', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('색상강도', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/20대 총선.csv'

# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('20대 총선', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('색상강도', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/21대 총선.csv'


# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('21대 총선', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('색상강도', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/22대 총선_비례.csv'


# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('22대 총선(비례)', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('색상강도', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/22대 총선.csv'


df = pd.read_csv(file_path, encoding='utf-8')

# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('22대 총선', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('색상강도', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/19대 총선_비례.csv'



# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('19대 총선 비례대표 득표율 차이', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('득표율 차이', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/20대 총선_비례.csv'


# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('20대 총선 비례대표 득표율 차이', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('득표율 차이', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm

# 한글 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 설치된 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)
plt.rc('font', family='NanumGothic')

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# 파일 경로 설정 (Google Drive 내의 경로 설정)
file_path = '/content/drive/My Drive/data/21대 총선_비례.csv'


# 히트맵 생성
plt.figure(figsize=(12, 8))
heatmap_data = df.pivot_table(index='선거구명', values='여득표율 - 야득표율')

ax = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', center=0, linewidths=.5, cbar_kws={'label': '득표율 차이'})
ax.set_title('21대 총선 비례대표 득표율 차이', fontproperties=fontprop, fontsize=16)
ax.set_xlabel('득표율 차이', fontproperties=fontprop, fontsize=12)
ax.set_ylabel('선거구명', fontproperties=fontprop, fontsize=12)

plt.xticks(rotation=45, ha='right', fontproperties=fontprop, fontsize=10)
plt.yticks(rotation=0, fontproperties=fontprop, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 46301 (\N{HANGUL SYLLABLE DEUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
# ...
